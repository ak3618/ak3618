# %%
def describe_pet(animal_type,pet_name):
    """ describe about the pet information"""
    print(f"I have a {animal_type}")
    print(f"\n My (animal_type)'s name is {pet_name}")

# %%
describe_pet('dog','brunao')
# Out:
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
# ...
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-3-946ff80966dc> in <module>
# ----> 1 describe_pet('dog','brunao')
#
# <ipython-input-2-9af98292877d> in describe_pet(animal_type, pet_name)
#       3     print(f"I have a {animal_type}")
#       4     print(f"\n My (animal_type)'s name is {pet_name}")
# ----> 5     describe_pet('dog','brunao')
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-2-9af98292877d> in describe_pet(animal_type, pet_name)
#       3     print(f"I have a {animal_type}")
#       4     print(f"\n My (animal_type)'s name is {pet_name}")
# ----> 5     describe_pet('dog','brunao')
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
def describe_pet(animal_type,pet_name):
    """ describe about the pet information"""
    print(f"I have a {animal_type}")
    print(f"My (animal_type)'s name is {pet_name}")

# %%
describe_pet('dog','bruno')
# Out:
# I have a dog
#
#  My (animal_type)'s name is bruno
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
# ...
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-4-194981011583> in <module>
# ----> 1 describe_pet('dog','bruno')
#
# <ipython-input-2-9af98292877d> in describe_pet(animal_type, pet_name)
#       3     print(f"I have a {animal_type}")
#       4     print(f"\n My (animal_type)'s name is {pet_name}")
# ----> 5     describe_pet('dog','brunao')
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-2-9af98292877d> in describe_pet(animal_type, pet_name)
#       3     print(f"I have a {animal_type}")
#       4     print(f"\n My (animal_type)'s name is {pet_name}")
# ----> 5     describe_pet('dog','brunao')
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
describe_pet('cat','snowbell')
# Out:
# I have a cat
#
#  My (animal_type)'s name is snowbell
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
# ...
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-5-72143d2b42d2> in <module>
# ----> 1 describe_pet('cat','snowbell')
#
# <ipython-input-2-9af98292877d> in describe_pet(animal_type, pet_name)
#       3     print(f"I have a {animal_type}")
#       4     print(f"\n My (animal_type)'s name is {pet_name}")
# ----> 5     describe_pet('dog','brunao')
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-2-9af98292877d> in describe_pet(animal_type, pet_name)
#       3     print(f"I have a {animal_type}")
#       4     print(f"\n My (animal_type)'s name is {pet_name}")
# ----> 5     describe_pet('dog','brunao')
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
 describe_pet('rex','dog')
# Out:
# I have a rex
#
#  My (animal_type)'s name is dog
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
# ...
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-6-9556252bacb1> in <module>
# ----> 1 describe_pet('rex','dog')
#
# <ipython-input-2-9af98292877d> in describe_pet(animal_type, pet_name)
#       3     print(f"I have a {animal_type}")
#       4     print(f"\n My (animal_type)'s name is {pet_name}")
# ----> 5     describe_pet('dog','brunao')
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-2-9af98292877d> in describe_pet(animal_type, pet_name)
#       3     print(f"I have a {animal_type}")
#       4     print(f"\n My (animal_type)'s name is {pet_name}")
# ----> 5     describe_pet('dog','brunao')
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
#positional arguments

# %%
#enhancment of code:no need to worry about position

# %%
describe_pet(pet_name='rex',animal_type='dog')
# Out:
# I have a dog
#
#  My (animal_type)'s name is rex
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
# ...
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-7-41e12bfd590f> in <module>
# ----> 1 describe_pet(pet_name='rex',animal_type='dog')
#
# <ipython-input-2-9af98292877d> in describe_pet(animal_type, pet_name)
#       3     print(f"I have a {animal_type}")
#       4     print(f"\n My (animal_type)'s name is {pet_name}")
# ----> 5     describe_pet('dog','brunao')
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-2-9af98292877d> in describe_pet(animal_type, pet_name)
#       3     print(f"I have a {animal_type}")
#       4     print(f"\n My (animal_type)'s name is {pet_name}")
# ----> 5     describe_pet('dog','brunao')
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
describe_pet('parrot','x')
# Out:
# I have a parrot
#
#  My (animal_type)'s name is x
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
# ...
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# I have a dog
#
#  My (animal_type)'s name is brunao
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-8-85717b7976cb> in <module>
# ----> 1 describe_pet('parrot','x')
#
# <ipython-input-2-9af98292877d> in describe_pet(animal_type, pet_name)
#       3     print(f"I have a {animal_type}")
#       4     print(f"\n My (animal_type)'s name is {pet_name}")
# ----> 5     describe_pet('dog','brunao')
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-2-9af98292877d> in describe_pet(animal_type, pet_name)
#       3     print(f"I have a {animal_type}")
#       4     print(f"\n My (animal_type)'s name is {pet_name}")
# ----> 5     describe_pet('dog','brunao')
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
